# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt

# %%
sys.path.append('../readmaroc')

# %%
from maroc_data import MarocData, Header

# %%
input_file = '../data/Run000109218.dat'

# %%
data = MarocData(input_file)

# %%
board=23

# %%
board_data = data.board_data(board)
pedestal = data._avg_data(board)
noise = data._noise(board)
header_data = data.header_board(board)
n_events = [Header(i).trigg_n_TS for i in header_data][1:]
ts = [Header(i).TS for i in header_data][1:]
ts_fine = [Header(i).TS_fine for i in header_data][1:]

# %%
for evt in n_events:
    if np.any(board_data[evt]-pedestal>=10*noise):
        print(evt, ts[evt], ts_fine[evt])
        plt.plot(np.arange(320), board_data[evt])
        plt.ylim(0,2000)
        plt.title(evt)
        plt.show()
# Out:
# 43 110337032 [3515481136 3515481118 3511445602 3528172306 3506593494 3515481138
#  3515481124 3511445606 3528172372 3506593488]
# 434 820179118 [475923918 475923928 475923872 475923956 475923960 475923920 475923932
#  475923884 470026250 475923962]
# 443 835434766 [964012966 964012998 902497340 964012986 964108924 964012990 964012998
#  891321796 911787990 964108928]
# 461 857297725 [1663721735 1663721726 1649857092 1657700340 1649856966 1663721674
#  1657700370 1649857092 1657700348 1648514408]
# 522 972190369 [1014928726 1015129866 1015129818 1014928152 1042171212 1014928752
#  1014928720 1015129820 1005073718 1042171214]
# 549 1010713835 [2268312762 2262298224 2262298236 2262298226 2278068018 2268312762
#  2262298244 2262298068 2226855448 2278068018]
# 561 1035540044 [3056885122 3051435016 3068402822 3051434700 3065003620 3051434998
#  3051435014 3068402826 3051244204 3065003632]
# 681 1238151397 [962825592 952539994 952540046 945449170 952539648 962825606 945449276
#  936677756 945449232 952539666]
# 820 1498635213 [711681532 711681568 701918316 711681372 711682954 711681556 711681568
#  701918316 711681468 711682966]
# 829 1511347804 [1118489530 1118489572 1112346908 1118489492 1112345828 1118308136
#  1118308144 1112345740 1118489516 1112345830]
# 880 1617762700 [221467778 221467820 221467794 221017396 221467754 221467796 221467822
#  221467798 221017404 221467764]
# 896 1653798112 [1377125904 1369609520 1332331716 1381927360 1346137974 1370039518
#  1369609538 1332331718 1381927378 1346137972]
# 1061 1972231308 [2981859798 2973501494 2981859746 2981859836 2981859842 2981859964
#  2981859996 2981859958 2979898088 2957138938]

# %%
ts_23 = ts[443]
ts_fine_23 = ts_fine[443]

# %%
ts_23
# Out:
# 835434766

# %%
ts_fine_23
# Out:
# array([964012966, 964012998, 902497340, 964012986, 964108924, 964012990,
#        964012998, 891321796, 911787990, 964108928])

# %%
ts_23 = np.asarray([Header(i).TS for i in data.header_board(23)][1:])

# %%
events_tot = []
ts_tot = []
for board in data.active_boards:
    board_data = data.header_board(board)
    ts = [Header(i).TS for i in board_data][1:]
    n_events = [Header(i).trigg_n_TS for i in board_data][1:]
    events_tot.append(n_events)
    ts_tot.append(ts)

# %%
padded_events = np.zeros((data.n_active_boards,np.max(np.unique(np.hstack(events_tot)))))
padded_ts = np.zeros((data.n_active_boards,np.max(np.unique(np.hstack(events_tot)))))

# %%
for i, b in enumerate(data.active_boards):
    unique_event_id = np.unique(events_tot[i])
    unique_ts = np.unique(ts_tot[i])#-ts_tot[i][0])
    padded_events[i][unique_event_id-1] = unique_event_id
    padded_ts[i][unique_event_id-1] = unique_ts

# %%
padded_ts[22][442]
# Out:
# 825888638.0

# %%
for board in data.active_boards:
    header_data = data.header_board(board)
    #n_events = np.asarray([Header(i).trigg_n_TS for i in header_data][1:])
    ts = np.asarray([Header(i).TS for i in header_data][1:])
    #ts_fine = np.asarray([Header(i).TS_fine for i in header_data][1:])
    if np.isclose(ts, ts_23):
        print(board)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-f214157368b8> in <module>
#       4     ts = np.asarray([Header(i).TS for i in header_data][1:])
#       5     #ts_fine = np.asarray([Header(i).TS_fine for i in header_data][1:])
# ----> 6     if np.isclose(ts, ts_23):
#       7         print(board)
#
# <__array_function__ internals> in isclose(*args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2288     yfin = isfinite(y)
#    2289     if all(xfin) and all(yfin):
# -> 2290         return within_tol(x, y, atol, rtol)
#    2291     else:
#    2292         finite = xfin & yfin
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/numeric.py in within_tol(x, y, atol, rtol)
#    2274     def within_tol(x, y, atol, rtol):
#    2275         with errstate(invalid='ignore'):
# -> 2276             return less_equal(abs(x-y), atol + rtol * abs(y))
#    2277
#    2278     x = asanyarray(a)
#
# ValueError: operands could not be broadcast together with shapes (1199,) (1196,)
