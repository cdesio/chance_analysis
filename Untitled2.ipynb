# %%
import os
import numpy as np

# %%
import re

# %%
regex = re.compile(r'\d+')

# %%
path_magda = '/newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/'

# %%
list_bad = []
with open('bad_files') as f:
    for l in f:
        list_bad.append(l)

# %%
list_bad
# Out:
# ['Vertexing_0_log.txt, Vertexing_1_log.txt, Vertexing_4.root,  Vertexing_5_log.txt, Vertexing_6_log.txt, Vertexing_7_log.txt, Vertexing_8_log.txt, Vertexing_9_log.txt, Vertexing_10_log.txt, Vertexing_11.root,  Vertexing_14_log.txt, Vertexing_15_log.txt, Vertexing_17_log.txt, Vertexing_18_log.txt, Vertexing_20_log.txt, Vertexing_21_log.txt, Vertexing_22_log.txt, Vertexing_23_log.txt, Vertexing_24_log.txt, Vertexing_27_log.txt, Vertexing_28_log.txt, Vertexing_30_log.txt, Vertexing_31_log.txt, Vertexing_34_log.txt, Vertexing_36_log.txt, Vertexing_39_log.txt, Vertexing_44.root,  Vertexing_55_log.txt, Vertexing_99_log.txt, Vertexing_111.root,  Vertexing_124.root, Vertexing_135.root,  Vertexing_141.root, Vertexing_155.root,  Vertexing_161_log.txt, Vertexing_188.root, Vertexing_199.root, Vertexing_222.root, Vertexing_233.root, Vertexing_294.root, Vertexing_305.root, Vertexing_316.root, Vertexing_327.root,  Vertexing_335_log.txt, Vertexing_338.root\n']

# %%
for fil in list_bad:
    print(fil.split(','))
# Out:
# ['Vertexing_0_log.txt', ' Vertexing_1_log.txt', ' Vertexing_4.root', '  Vertexing_5_log.txt', ' Vertexing_6_log.txt', ' Vertexing_7_log.txt', ' Vertexing_8_log.txt', ' Vertexing_9_log.txt', ' Vertexing_10_log.txt', ' Vertexing_11.root', '  Vertexing_14_log.txt', ' Vertexing_15_log.txt', ' Vertexing_17_log.txt', ' Vertexing_18_log.txt', ' Vertexing_20_log.txt', ' Vertexing_21_log.txt', ' Vertexing_22_log.txt', ' Vertexing_23_log.txt', ' Vertexing_24_log.txt', ' Vertexing_27_log.txt', ' Vertexing_28_log.txt', ' Vertexing_30_log.txt', ' Vertexing_31_log.txt', ' Vertexing_34_log.txt', ' Vertexing_36_log.txt', ' Vertexing_39_log.txt', ' Vertexing_44.root', '  Vertexing_55_log.txt', ' Vertexing_99_log.txt', ' Vertexing_111.root', '  Vertexing_124.root', ' Vertexing_135.root', '  Vertexing_141.root', ' Vertexing_155.root', '  Vertexing_161_log.txt', ' Vertexing_188.root', ' Vertexing_199.root', ' Vertexing_222.root', ' Vertexing_233.root', ' Vertexing_294.root', ' Vertexing_305.root', ' Ver
# ...

# %%
bad_idx = [int(regex.findall(fil)[0]) for fil in list_bad[0].split(',')]

# %%
count = 0
for i in range(350):
    if i not in bad_idx:
        count+=1
        print(path_magda+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_2.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_12.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_13.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_16.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_19.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_25.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_26.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_29.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_32.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_33.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_1/vertexing/Vertexing_35.root
# ...

# %%
count
# Out:
# 305

# %%
path_magda_2 = '/newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/'

# %%
list_bad = []
with open('bad_files_2') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(fil.split('\n')[0])
# Out:
# Vertexing_10_log.txt
# Vertexing_11_log.txt
# Vertexing_14_log.txt
# Vertexing_16_log.txt
# Vertexing_17_log.txt
# Vertexing_1_log.txt
# Vertexing_216_log.txt
# Vertexing_21_log.txt
# Vertexing_23_log.txt
# Vertexing_244_log.txt
# Vertexing_2_log.txt
# Vertexing_321_log.txt
# Vertexing_337_log.txt
# Vertexing_4_log.txt
# Vertexing_55_log.txt
# Vertexing_5_log.txt
# Vertexing_66_log.txt
# Vertexing_7_log.txt
# Vertexing_8_log.txt
# Vertexing_33.root
# Vertexing_22.root
# Vertexing_349.root
# Vertexing_0.root
# Vertexing_210.root
# Vertexing_142.root
# Vertexing_168.root
# Vertexing_111.root
# Vertexing_283.root
# Vertexing_166.root
# Vertexing_327.root
# Vertexing_316.root
# Vertexing_305.root
# Vertexing_338.root

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(350):
    if i not in bad_idx:
        count+=1
        print(path_magda_2+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_6.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_12.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_13.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_15.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_18.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_19.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_20.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_24.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_25.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_2/vertexing/Vertexing_26.root
# ...

# %%
count
# Out:
# 317

# %%
path_magda_3 = '/newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/'

# %%
list_bad = []
with open('bad_files_3') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(fil.split('\n')[0])
# Out:
# Vertexing_0_log.txt
# Vertexing_100_log.txt
# Vertexing_103_log.txt
# Vertexing_108_log.txt
# Vertexing_23_log.txt
# Vertexing_200.log.txt
# Vertexing_116_log.txt
# Vertexing_119_log.txt
# Vertexing_126_log.txt
# Vertexing_135_log.txt
# Vertexing_138_log.txt
# Vertexing_140_log.txt
# Vertexing_141_log.txt
# Vertexing_148_log.txt
# Vertexing_157_log.txt
# Vertexing_161_log.txt
# Vertexing_164_log.txt
# Vertexing_168_log.txt
# Vertexing_173_log.txt
# Vertexing_174_log.txt
# Vertexing_179_log.txt
# Vertexing_180_log.txt
# Vertexing_183_log.txt
# Vertexing_185_log.txt
# Vertexing_188_log.txt
# Vertexing_194_log.txt
# Vertexing_195_log.txt
# Vertexing_196_log.txt
# Vertexing_198_log.txt
# Vertexing_201_log.txt
# Vertexing_204_log.txt
# Vertexing_206_log.txt
# Vertexing_208_log.txt
# Vertexing_20_log.txt
# Vertexing_210_log.txt
# Vertexing_211_log.txt
# Vertexing_213_log.txt
# Vertexing_214_log.txt
# Vertexing_220_log.txt
# Vertexing_226_log.txt
# Vertexing_227_log.txt
# ...

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(350):
    if i not in bad_idx:
        count+=1
        print(path_magda_3+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_1.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_2.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_4.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_5.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_6.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_8.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_10.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_11.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_12.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_13.root
# ...

# %%
count
# Out:
# 273

# %%
path_magda_4 = '/newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/'

# %%
list_bad = []
with open('bad_files_4') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(fil.split('\n')[0])
# Out:
#  Vertexing_114_log.txt
# Vertexing_117_log.txt
# Vertexing_118_log.txt
# Vertexing_120_log.txt
# Vertexing_123_log.txt
# Vertexing_130_log.txt
# Vertexing_139_log.txt
# Vertexing_158_log.txt
# Vertexing_159_log.txt
# Vertexing_162_log.txt
# Vertexing_165_log.txt
# Vertexing_171_log.txt
# Vertexing_178_log.txt
# Vertexing_181_log.txt
# Vertexing_186_log.txt
# Vertexing_18_log.txt
# Vertexing_190_log.txt
# Vertexing_191_log.txt
# Vertexing_193_log.txt
# Vertexing_196_log.txt
# Vertexing_197_log.txt
# Vertexing_202_log.txt
# Vertexing_203_log.txt
# Vertexing_206_log.txt
# Vertexing_211_log.txt
# Vertexing_212_log.txt
# Vertexing_219_log.txt
# Vertexing_225_log.txt
# Vertexing_230_log.txt
# Vertexing_231_log.txt
# Vertexing_234_log.txt
# Vertexing_236_log.txt
# Vertexing_237_log.txt
# Vertexing_240_log.txt
# Vertexing_241_log.txt
# Vertexing_249_log.txt
# Vertexing_250_log.txt
# Vertexing_254_log.txt
# Vertexing_257_log.txt
# Vertexing_258_log.txt
# Vertexing_264_log.txt
# ...

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(350):
    if i not in bad_idx:
        count+=1
        print(path_magda_4+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_1.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_2.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_4.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_5.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_6.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_7.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_10.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_12.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_13.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_3/vertexing/Vertexing_14.root
# ...

# %%
count
# Out:
# 246

# %%
path_magda_3 = '/newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/'

# %%
list_bad = []
with open('bad_files_3') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(fil.split('\n')[0])
# Out:
# Vertexing_0_log.txt
# Vertexing_100_log.txt
# Vertexing_103_log.txt
# Vertexing_108_log.txt
# Vertexing_23_log.txt
# Vertexing_200.log.txt
# Vertexing_116_log.txt
# Vertexing_119_log.txt
# Vertexing_126_log.txt
# Vertexing_135_log.txt
# Vertexing_138_log.txt
# Vertexing_140_log.txt
# Vertexing_141_log.txt
# Vertexing_148_log.txt
# Vertexing_157_log.txt
# Vertexing_161_log.txt
# Vertexing_164_log.txt
# Vertexing_168_log.txt
# Vertexing_173_log.txt
# Vertexing_174_log.txt
# Vertexing_179_log.txt
# Vertexing_180_log.txt
# Vertexing_183_log.txt
# Vertexing_185_log.txt
# Vertexing_188_log.txt
# Vertexing_194_log.txt
# Vertexing_195_log.txt
# Vertexing_196_log.txt
# Vertexing_198_log.txt
# Vertexing_201_log.txt
# Vertexing_204_log.txt
# Vertexing_206_log.txt
# Vertexing_208_log.txt
# Vertexing_20_log.txt
# Vertexing_210_log.txt
# Vertexing_211_log.txt
# Vertexing_213_log.txt
# Vertexing_214_log.txt
# Vertexing_220_log.txt
# Vertexing_226_log.txt
# Vertexing_227_log.txt
# ...

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(350):
    if i not in bad_idx:
        count+=1
        print(path_magda_3+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_1.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_2.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_4.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_5.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_6.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_8.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_10.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_11.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_12.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_4/vertexing/Vertexing_13.root
# ...

# %%
count
# Out:
# 273

# %%
path_magda_vertexing_1 = '/newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/'

# %%
list_bad = []
with open('bad_files_hydr1') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(fil.split('\n')[0])
# Out:
# Vertexing_0_log.txt
# Vertexing_316_log.txt
# Vertexing_339_log.txt
# Vertexing_44_log.txt
# Vertexing_55_log.txt
# Vertexing_93_log.txt
# Vertexing_342.root
# Vertexing_10.root
# Vertexing_324.root
# Vertexing_332.root
# Vertexing_29.root
# Vertexing_19.root
# Vertexing_50.root
# Vertexing_64.root
# Vertexing_13.root
# Vertexing_22.root
# Vertexing_321.root
# Vertexing_315.root
# Vertexing_313.root
# Vertexing_314.root
# Vertexing_110.root
# Vertexing_144.root
# Vertexing_122.root
# Vertexing_133.root
# Vertexing_16.root
# Vertexing_311.root
# Vertexing_8.root
# Vertexing_286.root
# Vertexing_77.root
# Vertexing_2.root
# Vertexing_329.root
# Vertexing_99.root
# Vertexing_5.root
# Vertexing_47.root
# Vertexing_66.root
# Vertexing_23.root
# Vertexing_25.root
# Vertexing_43.root
# Vertexing_42.root
# Vertexing_88.root
# Vertexing_57.root
# Vertexing_7.root
# Vertexing_40.root
# Vertexing_11.root
# Vertexing_340.root
# Vertexing_33.root
# Vertexing_32.root
# Vertexing_220.root
# ...

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(350):
    if i not in bad_idx:
        count+=1
        print(path_magda_vertexing_1+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_1.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_4.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_6.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_12.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_14.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_15.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_17.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_18.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_20.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_1/vertexing/Vertexing_24.root
# ...

# %%
count
# Out:
# 282

# %%
path_magda_hydr2 = '/newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing '

# %%
list_bad = []
with open('bad_files_hydr2') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(regex.findall(fil.split('\n')[0])[0])
# Out:
# 146
# 305
# 283
# 302
# 312
# 323
# 330
# 285
# 306
# 291
# 282
# 331
# 202
# 337
# 281
# 210
# 99
# 326
# 166
# 320
# 324
# 77
# 66
# 44
# 110
# 244
# 289
# 334
# 344
# 339
# 222
# 345
# 133
# 313
# 310
# 11
# 342
# 298
# 286
# 309
# 317
# 296
# 0
# 303
# 159
# 327
# 341
# 321
# 33
# 328
# 155
# 299
# 292

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(350):
    if i not in bad_idx:
        count+=1
        print(path_magda_hydr2+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_1.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_2.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_4.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_5.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_6.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_7.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_8.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_10.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_12.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_2/vertexing Vertexing_13.root
# ...

# %%
count
# Out:
# 297

# %%
path_magda_hydr3 = '/newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/'

# %%
list_bad = []
with open('bad_files_hydr3') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(regex.findall(fil.split('\n')[0])[0])
# Out:
# 128
# 139
# 148
# 151
# 154
# 180
# 183
# 189
# 196
# 203
# 216
# 271
# 272
# 292
# 327
# 337
# 41
# 77
# 96
# 158
# 254
# 104
# 2
# 293
# 336
# 258
# 19
# 97
# 273
# 252
# 129
# 140
# 156
# 172

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(350):
    if i not in bad_idx:
        count+=1
        print(path_magda_hydr3+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_0.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_1.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_4.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_5.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_6.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_7.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_8.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_10.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_11.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_3/vertexing/Vertexing_12.root
# ...

# %%
count
# Out:
# 316

# %%
path_magda_hydr4 = '/newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/'

# %%
list_bad = []
with open('bad_files_hydr4') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(regex.findall(fil.split('\n')[0])[0])
# Out:
# 116
# 129
# 135
# 138
# 142
# 174
# 187
# 18
# 19
# 213
# 222
# 223
# 231
# 232
# 233
# 248
# 271
# 297
# 2
# 314
# 66
# 67
# 68
# 69
# 6
# 70
# 71
# 72
# 73
# 74
# 86
# 92
# 14
# 7
# 312
# 254
# 283
# 275
# 5

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(350):
    if i not in bad_idx:
        count+=1
        print(path_magda_hydr4+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_0.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_1.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_4.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_8.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_10.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_11.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_12.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_13.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_15.root
# /newhome/jp18291/g4work/testnew/chance_hydrogen_4/vertexing/Vertexing_16.root
# ...

# %%
count
# Out:
# 311

# %%
path_magda_bubbles2 = '/newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/'

# %%
list_bad = []
with open('bad_files_bubbles2') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(regex.findall(fil.split('\n')[0])[0])
# Out:
# 107
# 113
# 116
# 117
# 120
# 124
# 12
# 159
# 15
# 162
# 165
# 177
# 184
# 200
# 202
# 239
# 252
# 264
# 267
# 270
# 277
# 278
# 279
# 283
# 289
# 298
# 33
# 378
# 44
# 72
# 87
# 88
# 90
# 93
# 96
# 128
# 151
# 18
# 6
# 50
# 144
# 108
# 127
# 10
# 12

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(400):
    if i not in bad_idx:
        count+=1
        print(path_magda_bubbles2+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_0.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_1.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_2.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_4.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_5.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_7.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_8.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_11.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_2/vertexing/Vertexing_13.root
# ...

# %%
count
# Out:
# 356

# %%
path_magda_bubbles3 = '/newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/'

# %%
list_bad = []
with open('bad_files_bubbles3') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(regex.findall(fil.split('\n')[0])[0])
# Out:
# 185
# 205
# 224
# 227
# 299
# 309
# 332
# 386
# 389
# 395
# 46
# 78
# 373
# 363
# 371
# 374
# 255
# 127

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(400):
    if i not in bad_idx:
        count+=1
        print(path_magda_bubbles3+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_0.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_1.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_2.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_4.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_5.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_6.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_7.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_8.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_3/vertexing/Vertexing_10.root
# ...

# %%
count
# Out:
# 382

# %%
path_magda_bubbles1 = '/newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/'

# %%
list_bad = []
with open('bad_files_bubbles1') as f:
    for l in f:
        list_bad.append(l)

# %%
for fil in list_bad:
    print(regex.findall(fil.split('\n')[0])[0])
# Out:
# 0
# 111
# 156
# 18
# 222
# 283
# 294
# 305
# 316
# 327
# 338
# 349
# 11
# 166
# 251
# 296
# 295
# 298
# 210
# 280
# 299
# 177
# 244
# 278
# 79
# 302
# 147
# 146
# 279
# 148
# 209
# 297
# 99
# 300
# 254
# 188
# 271
# 199
# 218
# 175
# 110
# 140
# 233
# 155
# 274
# 303
# 90
# 92
# 258
# 259
# 172
# 86
# 85

# %%
bad_idx = [int(regex.findall(fil.split('\n')[0])[0]) for fil in list_bad]

# %%
count=0
for i in range(400):
    if i not in bad_idx:
        count+=1
        print(path_magda_bubbles1+'Vertexing_{}.root'.format(i))
# Out:
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_1.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_2.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_3.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_4.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_5.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_6.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_7.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_8.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_9.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_10.root
# /newhome/jp18291/g4work/testnew/chance_bitumen_bubbles_1/vertexing/Vertexing_12.root
# ...

# %%
count
# Out:
# 347
