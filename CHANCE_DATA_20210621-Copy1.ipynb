# %%
import os, sys
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
sys.path.append('../readmaroc/')

# %%
from maroc_data import MarocData

# %%
infile = '../readmaroc/data/farm/Run000039825.dat'

# %%
test_run = MarocData(infile)

# %%
test_run.n_active_boards
# Out:
# 22

# %%
board = 8
event = 39
fig, ax = plt.subplots(figsize=(8,6))
plt.title('Board {}, event {}'.format(board, event))
x=np.arange(320)
y = test_run.board_data(board)[event]
ax.plot(x,y, c='white')
ax.fill_between(x, y, color='blue')
ax.set_facecolor('k')
ax.set_ylim(0, 4000)
plt.grid()
plt.show()

# %%
pedestal = np.zeros((31, 320))
for board in range(1, 31):
    if board in test_run.active_boards:
        #for event in range(len(test_run.board_data(board))):
            #if np.any(test_run.board_data(board)[0]>= np.mean(test_run.board_data(board)[event])+200):
        print('board: {}'.format(board))
        pedestal[board]=np.mean(test_run.board_data(board), axis=0)
        plt.plot(np.arange(320), pedestal[board])
        plt.ylim(0,2000)
        plt.show()
# Out:
# board: 1
# board: 2
# board: 3
# board: 4
# board: 5
# board: 7
# board: 8
# board: 9
# board: 10
# board: 11
# board: 12
# board: 14
# board: 15
# board: 16
# board: 18
# board: 19
# board: 20
# board: 21
# board: 22
# board: 23
# board: 24
# board: 29

# %%
board = 8
event = 39
fig, ax = plt.subplots(figsize=(8,6))
plt.title('Board {}, event {}'.format(board, event))
x=np.arange(320)
y = test_run.board_data(board)[event] - pedestal[8]
ax.plot(x,y, c='white')
ax.fill_between(x, y, color='blue')
ax.set_facecolor('k')
ax.set_ylim(0, 4000)
plt.grid()
plt.show()

# %%
for board in range(1, 31):
    if board in test_run.active_boards:
        subtracted_pedestal = np.asarray(list(map(lambda a : a-pedestal[board], test_run.board_data(board))))
        for i, event in enumerate(subtracted_pedestal):
            if np.any(event>=300):
                print('board: {}, event: {}'.format(board, i))
                plt.figure(figsize=(8,6))
                plt.plot(np.arange(320), event)
                plt.ylim(0,2000)
                plt.show()
# Out:
# board: 1, event: 749
# board: 1, event: 970
# board: 1, event: 1046
# board: 1, event: 1713
# board: 1, event: 1949
# board: 1, event: 1983
# board: 2, event: 189
# board: 2, event: 720
# board: 2, event: 1079
# board: 2, event: 1427
# board: 3, event: 566
# board: 3, event: 1375
# board: 3, event: 1643
# board: 3, event: 1669
# board: 3, event: 1881
# board: 5, event: 7
# board: 5, event: 263
# board: 5, event: 519
# board: 5, event: 775
# board: 5, event: 1031
# board: 5, event: 1287
# board: 5, event: 1543
# board: 5, event: 1590
# board: 5, event: 1799
# board: 5, event: 2015
# board: 8, event: 1447
# board: 8, event: 1609
# board: 9, event: 477
# board: 9, event: 1634
# board: 9, event: 1871
# board: 9, event: 1972
# board: 10, event: 185
# board: 10, event: 619
# board: 10, event: 1050
# board: 10, event: 1121
# board: 11, event: 87
# board: 11, event: 153
# board: 11, event: 441
# board: 11, event: 1429
# board: 12, event: 1791
# board: 14, event: 44
# board: 14, event: 284
# ...

# %%
for board in range(1, 31):
    if board in test_run.active_boards:
        subtracted_pedestal = np.asarray(list(map(lambda a : a-pedestal[board], test_run.board_data(board))))
        for i, event in enumerate(subtracted_pedestal):
            if np.any(event>=300):
                print('board: {}, event: {}'.format(board, i))
# Out:
# board: 1, event: 749
# board: 1, event: 970
# board: 1, event: 1046
# board: 1, event: 1713
# board: 1, event: 1949
# board: 1, event: 1983
# board: 2, event: 189
# board: 2, event: 720
# board: 2, event: 1079
# board: 2, event: 1427
# board: 3, event: 566
# board: 3, event: 1375
# board: 3, event: 1643
# board: 3, event: 1669
# board: 3, event: 1881
# board: 5, event: 7
# board: 5, event: 263
# board: 5, event: 519
# board: 5, event: 775
# board: 5, event: 1031
# board: 5, event: 1287
# board: 5, event: 1543
# board: 5, event: 1590
# board: 5, event: 1799
# board: 5, event: 2015
# board: 8, event: 1447
# board: 8, event: 1609
# board: 9, event: 477
# board: 9, event: 1634
# board: 9, event: 1871
# board: 9, event: 1972
# board: 10, event: 185
# board: 10, event: 619
# board: 10, event: 1050
# board: 10, event: 1121
# board: 11, event: 87
# board: 11, event: 153
# board: 11, event: 441
# board: 11, event: 1429
# board: 12, event: 1791
# board: 14, event: 44
# board: 14, event: 284
# ...

# %%
for i in range(31):
    if i in test_run.active_boards:
        print(len(test_run.board_data(i)))
# Out:
# 2021
# 2003
# 2045
# 2024
# 2046
# 2026
# 2026
# 2026
# 1965
# 2005
# 1959
# 1951
# 1971
# 2012
# 1994
# 2034
# 1992
# 2053
# 2033
# 2054
# 2044
# 2028

# %%
plt.figure(figsize=(8,6))
plt.plot(np.arange(320), test_run.board_data(13)[377]-pedestal[13])
plt.plot(np.arange(320), test_run.board_data(23)[69]-pedestal[23])
plt.ylim(0,2000)
plt.show()

# %%
test_run.header[0][1:6]
# Out:
# array([3443008838, 3100013548,         10, 3169330824, 3029664252])

# %%
test_run.header[0][6:11]
# Out:
# array([3008839054, 3443008844, 3100013556, 3169330824,       4822])

# %%
test_run.header[0][11:21]
# Out:
# array([3469244118, 3372628944, 3008839056,         10,          3,
#                 0,          1,          2,          1,          1])

# %%
test_run.header[0][21:32]
# Out:
# array([0, 1, 3, 0, 5, 1, 1, 1, 1, 1, 5])

# %%
test_run.header[0][38]
# Out:
# 64

# %%
test_run.header[0]
# Out:
# array([3232286848, 3443008838, 3100013548,         10, 3169330824,
#        3029664252, 3008839054, 3443008844, 3100013556, 3169330824,
#              4822, 3469244118, 3372628944, 3008839056,         10,
#                 3,          0,          1,          2,          1,
#                 1,          0,          1,          3,          0,
#                 5,          1,          1,          1,          1,
#                 1,          5,   17584211,   17584211,   17584211,
#          17584211,   17584211,          5,         64])

# %%
test_run.header[1]
# Out:
# array([3232286849, 3431336322,         74,         10, 3431336126,
#        3131819900, 3325855196, 3431336094,         74, 3431336126,
#              4822, 3467624634, 3569212798, 3588349152,         10,
#                 5,          7,          3,          1,          6,
#                 4,          6,          3,          1,          5,
#                 5,          1,          1,          1,          1,
#                 1,          5,   15969168,   15969168,   15969168,
#          15969168,   15969168,          5,         64])
