# %%
import numpy as np
import pickle

# %%
dat = '../RpcHitsData/Run000011997.dat'

# %%
f = open(dat, "rb")
for i in range(10):
    print(f.readline())
# Out:
# b'\xa0\xc8\xa8\xc0\x98\x8ek\x8b4\xb2\xcbu\n'
# b'\x00\x00\x00>-g\x80Hl\xe4\x8c+\t\x00\x00@jfm\xe6l\xe4\x8c\xc4\xabx\xa9\xc2\xabx\xa9J\x12\xbd\xa9V\x12\xbd\xa9\x1eDw\x8a\n'
# ...
