# %%
import os, sys

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
sys.path.append('../readmaroc')

# %%
files = [os.path.join('../readmaroc/data/farm/',path) for path in os.listdir('../readmaroc/data/farm/') if path.endswith('dat') and path.startswith('Run00008'
)]

# %%
pedestal_file = '../readmaroc/data/farm/Pedestal_test.dat'

# %%
ped = MarocData(pedestal_file)

# %%
pedestal = np.zeros((31, 320))
for board in range(1, 31):
    if board in ped.active_boards:
        #for event in range(len(test_run.board_data(board))):
            #if np.any(test_run.board_data(board)[0]>= np.mean(test_run.board_data(board)[event])+200):
        print('board: {}'.format(board))
        pedestal[board]=np.mean(ped.board_data(board), axis=0)
        plt.plot(np.arange(320), pedestal[board])
        plt.ylim(0,2000)
        plt.show()
# Out:
# board: 1
# board: 2
# board: 3
# board: 4
# board: 5
# board: 6
# board: 7
# board: 8
# board: 9
# board: 10
# board: 11
# board: 12
# board: 13
# board: 14
# board: 15
# board: 16
# board: 17
# board: 18
# board: 19
# board: 20
# board: 22
# board: 23
# board: 24
# board: 25
# board: 26
# board: 27
# board: 28
# board: 29
# board: 30

# %%
files
# Out:
# ['../readmaroc/data/farm/Run000081526.dat',
#  '../readmaroc/data/farm/Run000085782.dat',
#  '../readmaroc/data/farm/Run000085781.dat',
#  '../readmaroc/data/farm/Run000084272.dat',
#  '../readmaroc/data/farm/Run000081988.dat',
#  '../readmaroc/data/farm/Run000084173.dat',
#  '../readmaroc/data/farm/Run000081950.dat',
#  '../readmaroc/data/farm/Run000081505.dat',
#  '../readmaroc/data/farm/Run000085820.dat',
#  '../readmaroc/data/farm/Run000080435.dat',
#  '../readmaroc/data/farm/Run000085809.dat']

# %%
from maroc_data import MarocData

# %%
test = MarocData(files[-1])

# %%
test.n_active_boards
# Out:
# 29

# %%
for b in [20, 23, 26, 29]:
    board = test.board_data(b)
    for evt in range(test.nevents_per_board(b)):
        if np.any(board[evt]-pedestal[b] > 200):
            plt.plot(np.arange(320), board[evt], label='data')
            plt.plot(np.arange(320), pedestal[b], label='pedestal')
            print('board: {}, evt: {}, TS: {}'.format(b, evt, test.header_board(b)[evt][2]))
            plt.ylim(0,25x00)
            plt.legend(loc='upper right')
            plt.show()
# Out:
# board: 20, evt: 578, TS: 1640647951
# board: 20, evt: 712, TS: 879379293
# board: 23, evt: 40, TS: 603395161
# board: 23, evt: 182, TS: 2264389215
# board: 23, evt: 241, TS: 3040830985
# board: 23, evt: 255, TS: 3243753443
# board: 23, evt: 497, TS: 3963754413
# board: 23, evt: 570, TS: 1334083942
# board: 23, evt: 652, TS: 3343968856
# board: 23, evt: 691, TS: 350842267
# board: 23, evt: 789, TS: 2759366161
# board: 23, evt: 975, TS: 3380778556
# board: 23, evt: 981, TS: 3453046368
# board: 23, evt: 1006, TS: 4150814428
# board: 26, evt: 277, TS: 3726745292
# board: 26, evt: 325, TS: 280178383
# board: 26, evt: 361, TS: 1100845370
# board: 26, evt: 393, TS: 1669814897
# board: 26, evt: 423, TS: 2388917118
# board: 26, evt: 444, TS: 2921276267
# board: 26, evt: 581, TS: 1656544418
# board: 26, evt: 622, TS: 2723293583
# board: 26, evt: 662, TS: 3603698796
# board: 26, evt: 805, TS: 3119882976
# board: 26, evt: 848, TS: 328971518
# board: 26, evt: 901, TS: 1645305512
# board: 29, evt: 34, TS: 523823540
# board: 29, evt: 277, TS: 3721698076
# board: 29, evt: 361, TS: 1095798154
# board: 29, evt: 393, TS: 1664767682
# board: 29, evt: 561, TS: 1131817633
# board: 29, evt: 960, TS: 3046688785
# board: 29, evt: 1100, TS: 1797833385

# %%
for b in [2, 5, 8, 11, 14]:
    board = test.board_data(b)
    for evt in range(test.nevents_per_board(b)):
        if np.any(board[evt]-pedestal[b] > 300):
            plt.plot(np.arange(320), board[evt], label='data')
            plt.plot(np.arange(320), pedestal[b], label='pedestal')
            print('board: {}, evt: {}, TS: {}'.format(b, evt, test.header_board(b)[evt][2]))
            plt.ylim(0,2500)
            plt.legend(loc='upper right')
            plt.show()
# Out:
# board: 2, evt: 332, TS: 508564491
# board: 5, evt: 7, TS: 166441058
# board: 5, evt: 263, TS: 3441741922
# board: 5, evt: 502, TS: 4123964488
# board: 5, evt: 519, TS: 146525734
# board: 5, evt: 704, TS: 636661677
# board: 5, evt: 775, TS: 2535985200
# board: 5, evt: 1031, TS: 411726388
# board: 14, evt: 158, TS: 1962766856
# board: 14, evt: 277, TS: 3748837987
# board: 14, evt: 361, TS: 1122938065
# board: 14, evt: 422, TS: 2400731291
# board: 14, evt: 622, TS: 2745386278
# board: 14, evt: 662, TS: 3625791491
# board: 14, evt: 954, TS: 2930259101

# %%
for b in [3, 6, 9, 12, 15]:
    board = test.board_data(b)
    for evt in range(test.nevents_per_board(b)):
        if np.any(board[evt]-pedestal[b] > 300):
            plt.plot(np.arange(320), board[evt], label='data')
            plt.plot(np.arange(320), pedestal[b], label='pedestal')
            print('board: {}, evt: {}, TS: {}'.format(b, evt, test.header_board(b)[evt][2]))
            plt.ylim(0,2500)
            plt.legend(loc='upper right')
            plt.show()
# Out:
# board: 12, evt: 444, TS: 2946599598
# board: 12, evt: 622, TS: 2748616914
# board: 15, evt: 277, TS: 3747554939
# board: 15, evt: 361, TS: 1121655017
# board: 15, evt: 481, TS: 3757480282
# board: 15, evt: 482, TS: 3766000810
# board: 15, evt: 524, TS: 290843577
# board: 15, evt: 680, TS: 64983863
# board: 15, evt: 815, TS: 3468679319
# board: 15, evt: 954, TS: 2928976053

# %%
for b in [16, 19, 22, 25, 28]:
    board = test.board_data(b)
    for evt in range(test.nevents_per_board(b)):
        if np.any(board[evt]-pedestal[b] > 300):
            plt.plot(np.arange(320), board[evt], label='data')
            plt.plot(np.arange(320), pedestal[b], label='pedestal')
            print('board: {}, evt: {}, TS: {}'.format(b, evt, test.header_board(b)[evt][2]))
            #plt.ylim(0,2500)
            plt.legend(loc='upper right')
            plt.show()
# Out:
# board: 16, evt: 255, TS: 3256546244
# board: 16, evt: 303, TS: 4227835987
# board: 16, evt: 511, TS: 4277697828
# board: 16, evt: 767, TS: 2331042757
# board: 16, evt: 844, TS: 191576789
# board: 16, evt: 1023, TS: 117270882
# board: 16, evt: 1178, TS: 3577725746
# board: 25, evt: 12, TS: 198744313
# board: 25, evt: 277, TS: 3729168406
# board: 25, evt: 342, TS: 691980321
# board: 25, evt: 393, TS: 1672238012
# board: 25, evt: 482, TS: 3747614277
# board: 25, evt: 581, TS: 1658967533
# board: 25, evt: 622, TS: 2725716698
# board: 25, evt: 1050, TS: 709122101
# board: 28, evt: 177, TS: 2223465358
# board: 28, evt: 235, TS: 2983367957
# board: 28, evt: 277, TS: 3723190456
# board: 28, evt: 296, TS: 4110201996
# board: 28, evt: 361, TS: 1097290534
# board: 28, evt: 393, TS: 1666260062
# board: 28, evt: 441, TS: 2861323213
# board: 28, evt: 451, TS: 3041422992
# board: 28, evt: 482, TS: 3741636327
# board: 28, evt: 581, TS: 1652989583
# board: 28, evt: 622, TS: 2719738748
# board: 28, evt: 655, TS: 3424447993
# board: 28, evt: 673, TS: 4045139222
# board: 28, evt: 854, TS: 532022134
# board: 28, evt: 901, TS: 1641750677
# board: 28, evt: 954, TS: 2904611570
# board: 28, evt: 960, TS: 3048181165
# board: 28, evt: 1082, TS: 1484178502
# board: 28, evt: 1140, TS: 2792067963
# board: 28, evt: 1171, TS: 3470854531
# board: 28, evt: 1180, TS: 3567261226

# %%
test_1 = MarocData('../data/0802/Run000087892.dat')

# %%
for b in [20, 23, 26, 29]:
    board = test_1.board_data(b)
    for evt in range(test.nevents_per_board(b)):
        if np.any(board[evt]-pedestal[b] > 200):
            plt.plot(np.arange(320), board[evt], label='data')
            plt.plot(np.arange(320), pedestal[b], label='pedestal')
            print('board: {}, evt: {}, TS: {}'.format(b, evt, test_1.header_board(b)[evt][2]))
            plt.ylim(0,2500)
            plt.legend(loc='upper right')
            plt.show()
# Out:
# board: 20, evt: 79, TS: 491916118
# board: 20, evt: 929, TS: 4287282855
# board: 23, evt: 316, TS: 1651732110
# board: 23, evt: 445, TS: 2246058247
# board: 23, evt: 452, TS: 2273171403
# board: 23, evt: 513, TS: 2601297952
# board: 26, evt: 222, TS: 1175978962
# board: 29, evt: 366, TS: 1898447575
# board: 29, evt: 843, TS: 3929449061
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-99a81b824dfa> in <module>
#       2     board = test_1.board_data(b)
#       3     for evt in range(test.nevents_per_board(b)):
# ----> 4         if np.any(board[evt]-pedestal[b] > 200):
#       5             plt.plot(np.arange(320), board[evt], label='data')
#       6             plt.plot(np.arange(320), pedestal[b], label='pedestal')
#
# IndexError: index 1200 is out of bounds for axis 0 with size 1200
