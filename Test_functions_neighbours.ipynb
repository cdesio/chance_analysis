# %%
# %load_ext notexbook

# %%
# %texify
# Out:
# <style type="text/css">
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
# ...
#                          FONTS
#
#     FONT WEIGHT MAP:
#     ----------------
#     100: Ultra Light
#     200: Thin
#     300: Light
#     400: Regular (normal)
#     500: Medium
#     600: Semi-bold
#     700: Bold
#     800: Heavy
#     900: Black
#
#     Font faces:
#         - ====================================|=======================
#         -              Scope                  | Font Family Name
#         - ====================================| ======================
#         - Markdown Display (Computer Modern)    (CMU Serif)
#         - Markdown Display monospace            (CMU Typewriter Text)
#         - Markdown Edit    monospace            (Hack)
# ...

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# %matplotlib widget

# %%
from bins import Hist, Bin

# %%
histogram21l = Hist('data/largedrum_21L_dense_MedianCut_3cmVoxel_all.discriminator.root')
histogram_bitumen = Hist(infile='data/largedrum_onlybitumen_dense_newmetrics_3cmVoxel_April2021.discriminator.root')
histogram_hydrogen = Hist(infile='data/largedrum_onlyhydrogen_dense_newmetrics_3cmVoxel_April2021.discriminator.root')

# %%
centre_21l = histogram21l.cube_select(edge_cut=(Bin(-100,100), Bin(-100,100), Bin(-100,100)))
centre_bitumen = histogram_bitumen.cube_select(edge_cut=(Bin(-100,100), Bin(-100,100), Bin(-100,100)))
centre_hydrogen = histogram_hydrogen.cube_select(edge_cut=(Bin(-100,100), Bin(-100,100), Bin(-100,100)))

# %%
centre_cyl_21l = histogram21l.cylinder_select(threshold=100, edge_cut=(Bin(-100,100),Bin(-100,100),Bin(-100,100)))
centre_cyl_bitumen = histogram_bitumen.cylinder_select(threshold=100, edge_cut=(Bin(-100,100),Bin(-100,100),Bin(-100,100)))
centre_cyl_hydrogen = histogram_hydrogen.cylinder_select(threshold=100, edge_cut=(Bin(-100,100),Bin(-100,100),Bin(-100,100)))

# %%
drum_21l =  histogram21l.cylinder_select(threshold=290, edge_cut=(Bin(-440,440),Bin(-450,550),Bin(-500,500)))
drum_bitumen = histogram_bitumen.cylinder_select(threshold=290, edge_cut=(Bin(-440,440),Bin(-450,550),Bin(-500,500)))
drum_hydrogen = histogram_hydrogen.cylinder_select(threshold=290, edge_cut=(Bin(-440,440),Bin(-450,550),Bin(-500,500)))

# %%
stats_air_air_21l, stats_air_bt_21l = centre_cyl_21l.neighbour_count(centre='above')

# %%
plt.figure(figsize=(7,5))
plot_kwds = {'density': False, 'linewidth':"1.5", 'histtype': u'step', "bins":20}
plt.hist(stats_air_bt_21l.values(), label='neighbours < 11.26', edgecolor='red', **plot_kwds)
plt.hist(stats_air_air_21l.values(), label='neighbours >= 11.26', edgecolor='blue', **plot_kwds)
plt.title("central voxels containing air")
plt.xlabel('neighbour voxels count')
plt.legend(loc='upper center')

#plt.savefig("neighbour_voxels_ct.png") 
plt.show()

# %%
stats_air_air_drum_bt, stats_air_bt_drum_bt = drum_bitumen.neighbour_count(centre='above')

# %%
plt.figure(figsize=(7,5))
plot_kwds = {'density': False, 'linewidth':"1.5", 'histtype': u'step', "bins":20}
plt.hist(stats_air_bt_drum_bt.values(), label='neighbours < 11.26', edgecolor='red', **plot_kwds)
plt.hist(stats_air_air_drum_bt.values(), label='neighbours >= 11.26', edgecolor='blue', **plot_kwds)
plt.title("central voxels containing air")
plt.xlabel('neighbour voxels count')
plt.legend(loc='upper center')

#plt.savefig("neighbour_voxels_ct.png") 
plt.show()

# %%
stats_air_air_drum_bt, stats_air_bt_drum_bt = drum_hydrogen.neighbour_count(centre='below')

# %%
plt.figure(figsize=(7,5))
plot_kwds = {'density': False, 'linewidth':"1.5", 'histtype': u'step', "bins":20}
plt.hist(stats_air_bt_drum_bt.values(), label='neighbours < 11.26', edgecolor='red', **plot_kwds)
plt.hist(stats_air_air_drum_bt.values(), label='neighbours >= 11.26', edgecolor='blue', **plot_kwds)
plt.title("central voxels containing bitumen")
plt.xlabel('neighbour voxels count')
plt.legend(loc='upper center')

#plt.savefig("neighbour_voxels_ct.png") 
plt.show()

# %%
air_air, air_bt = histogram21l.cylinder_select(threshold=300, edge_cut=(Bin(-400,400), Bin(-300,300), Bin(-300,300))).neighbour_count(centre='below')

# %%
plt.figure(figsize=(7,5))
plot_kwds = {'density': False, 'linewidth':"1.5", 'histtype': u'step', "bins":20}
plt.hist(air_bt.values(), label='neighbours < 11.26', edgecolor='red', **plot_kwds)
plt.hist(air_air.values(), label='neighbours >= 11.26', edgecolor='blue', **plot_kwds)
plt.title("central voxels containing bitumen")
plt.xlabel('neighbour voxels count')
plt.legend(loc='upper center')

#plt.savefig("neighbour_voxels_ct.png") 
plt.show()

# %%
air_air, air_bt = histogram_hydrogen.cylinder_select(threshold=300, edge_cut=(Bin(-400,400), Bin(-300,300), Bin(-300,300))).neighbour_count(centre='below')

# %%
plt.figure(figsize=(7,5))
plot_kwds = {'density': False, 'linewidth':"1.5", 'histtype': u'step', "bins":20}
plt.hist(air_bt.values(), label='neighbours < 11.26', edgecolor='red', **plot_kwds)
plt.hist(air_air.values(), label='neighbours >= 11.26', edgecolor='blue', **plot_kwds)
plt.title("central voxels containing air")
plt.xlabel('neighbour voxels count')
plt.legend(loc='upper center')

#plt.savefig("neighbour_voxels_ct.png") 
plt.show()

# %%
air_air, air_bt = histogram_bitumen.cylinder_select(threshold=300, edge_cut=(Bin(-400,400), Bin(-300,300), Bin(-300,300))).neighbour_count(centre='below')

# %%
plt.figure(figsize=(7,5))
plot_kwds = {'density': False, 'linewidth':"1.5", 'histtype': u'step', "bins":20}
plt.hist(air_bt.values(), label='neighbours < 11.26', edgecolor='red', **plot_kwds)
plt.hist(air_air.values(), label='neighbours >= 11.26', edgecolor='blue', **plot_kwds)
plt.title("central voxels containing air")
plt.xlabel('neighbour voxels count')
plt.legend(loc='upper center')

#plt.savefig("neighbour_voxels_ct.png") 
plt.show()

# %%
bt_air, bt_bt = drum_21l.neighbour_count(centre='below')

# %%
plt.figure(figsize=(7,5))
plot_kwds = {'density': False, 'linewidth':"1.5", 'histtype': u'step', "bins":20}
plt.hist(bt_bt.values(), label='neighbours < 11.26', edgecolor='red', **plot_kwds)
plt.hist(bt_air.values(), label='neighbours >= 11.26', edgecolor='blue', **plot_kwds)
plt.title("central voxels containing air")
plt.xlabel('neighbour voxels count')
plt.legend(loc='upper center')

#plt.savefig("neighbour_voxels_ct.png") 
plt.show()

# %%
hist_padded = np.zeros_like(histogram21l.histogram)

# %%
drum_21l = histogram21l.cylinder_select(threshold=290, edge_cut=(Bin(-440,440),Bin(-450,550),Bin(-500,500)))

hist = drum_21l.histogram
cmap = plt.cm.get_cmap('jet',20)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111,projection="3d")

xx, yy, zz = np.where(hist >= 11.265)
pnt3d = ax.scatter(xx, yy, zz, c=hist[hist>=11.265], 
                   cmap=cmap, s=10, alpha=.9)
cbar=plt.colorbar(pnt3d, shrink=0.6)
ax.set_xlabel('Z')
ax.set_ylabel('X')
ax.set_zlabel('Y')
#ax.set_xlim(0,66)
#ax.set_ylim(0,66)
#ax.set_zlim(0,33)
ax.view_init(elev=10, azim=20)
plt.show()

# %%
drum_21l.extent
# Out:
# AxesInfo(x=Bin(left=-1000.0, right=1000.0), y=Bin(left=-303.030303030303, right=272.72727272727275), z=Bin(left=-287.8787878787879, right=287.8787878787879))

# %%
drum_21l.original_axes.z
# Out:
# array([Bin(left=-500.0, right=-469.6969696969697),
#        Bin(left=-469.6969696969697, right=-439.3939393939394),
#        Bin(left=-439.3939393939394, right=-409.0909090909091),
#        Bin(left=-409.0909090909091, right=-378.78787878787875),
#        Bin(left=-378.78787878787875, right=-348.4848484848485),
#        Bin(left=-348.4848484848485, right=-318.1818181818182),
#        Bin(left=-318.1818181818182, right=-287.8787878787879),
#        Bin(left=-287.8787878787879, right=-257.57575757575756),
#        Bin(left=-257.57575757575756, right=-227.27272727272725),
#        Bin(left=-227.27272727272725, right=-196.96969696969694),
#        Bin(left=-196.96969696969694, right=-166.66666666666663),
#        Bin(left=-166.66666666666663, right=-136.36363636363637),
#        Bin(left=-136.36363636363637, right=-106.06060606060606),
#        Bin(left=-106.06060606060606, right=-75.75757575757575),
#        Bin(left=-75.75757575757575, right=-45.45454545454544),
# ...

# %%
data = histogram_bitumen
from matplotlib import cm, colors
cmap = cm.get_cmap('jet', 20)
norm = colors.Normalize(vmin=11.265, vmax=15)
cmap.set_bad(color='white')

air_histogram = np.copy(data.histogram)
air_histogram[air_histogram<11.265]=0
#set the background as white (default was min value of cmap -> blue) 
masked_hist_air = np.ma.masked_where(air_histogram == 0, air_histogram)
masked_hist = np.ma.masked_where(data.histogram == 0, data.histogram)

for i in range(7, 26):#filtered_hist.shape[2]):
    fig, ax = plt.subplots(1,2, figsize= (14,5),sharex=True, sharey=True)
    fig.suptitle('z={}'.format(i))
    im1 = ax[0].imshow(np.swapaxes(masked_hist_air, 0,1)[:,:,i], cmap=cmap, norm=norm, 
                       extent=[data.extent.x.left,data.extent.x.right,
                              data.extent.y.left,data.extent.y.right])
    im2 = ax[1].imshow(np.swapaxes(masked_hist,0,1)[:,:,i], cmap=cmap, norm=norm, 
                       extent=[data.extent.x.left,data.extent.x.right,
                              data.extent.y.left,data.extent.y.right]) #map (0,66) to (-1000,1000)
    
    ax[0].set_title('d>=11.26')
    ax[1].set_title('all metric values')
    
    fig.colorbar(im1, ax=ax[0], shrink=1)
    fig.colorbar(im2, ax=ax[1], shrink=1)
    plt.tight_layout()
    #plt.savefig("slices_z_{}.png".format(i))
    plt.show()

# %%
drum_21l = histogram21l.cylinder_select(threshold=300, edge_cut=(Bin(-1000,1000), Bin(-300,300), Bin(-300,300)))

# %%
data = centre_21l
from matplotlib import cm, colors
cmap = cm.get_cmap('jet', 20)
norm = colors.Normalize(vmin=11.265, vmax=15)
cmap.set_bad(color='white')

air_histogram = np.copy(data.histogram)
air_histogram[air_histogram<11.265]=0
#set the background as white (default was min value of cmap -> blue) 
masked_hist_air = np.ma.masked_where(air_histogram == 0, air_histogram)
masked_hist = np.ma.masked_where(data.histogram == 0, data.histogram)

for i in range(data.histogram.shape[2]):#filtered_hist.shape[2]):
    fig, ax = plt.subplots(1,2, figsize= (14,5),sharex=True, sharey=True)
    fig.suptitle('z={}'.format(i))
    im1 = ax[0].imshow(np.swapaxes(masked_hist_air, 0,1)[:,:,i], cmap=cmap, norm=norm, 
                       extent=[data.extent.x.left,data.extent.x.right,
                              data.extent.y.left,data.extent.y.right])
    im2 = ax[1].imshow(np.swapaxes(masked_hist,0,1)[:,:,i], cmap=cmap, norm=norm, 
                       extent=[data.extent.x.left,data.extent.x.right,
                              data.extent.y.left,data.extent.y.right]) #map (0,66) to (-1000,1000)
    
    ax[0].set_title('d>=11.26')
    ax[1].set_title('all metric values')
    
    fig.colorbar(im1, ax=ax[0], shrink=1)
    fig.colorbar(im2, ax=ax[1], shrink=1)
    plt.tight_layout()
    #plt.savefig("slices_z_{}.png".format(i))
    plt.show()

# %%
histogram.shape

# %%
histogram21l.axes.x

# %%
centre_21l = histogram21l.cube_select(Bin(-100,100), Bin(-100,100), Bin(-100,100))

# %%
cyl_21l = histogram21l.cylinder_select(threshold=300, edge_cut=(Bin(-1000,1000), Bin(-300,300), Bin(-300,300)))

# %%
cyl_21l.shape
# Out:
# (66, 14, 14)
