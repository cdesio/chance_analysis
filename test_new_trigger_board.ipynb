# %%
import os, sys

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
sys.path.append('../readmaroc/')

# %%
from maroc_data import MarocData, Header

# %%
input_file = '../data/Run000109218.dat'

# %%
data = MarocData(input_file)

# %%
for b in data.active_boards:
    board_data = data.board_data(b)
    n_events = len(board_data)
    pedestal = data._avg_data(b)
    noise = data._noise(b)
    header_data = maroc_data.header_board(b)
    ts = [Header(i).TS for i in board_data][1:]
    n_events = [Header(i).trigg_n_TS for i in board_data][1:] 
    
    for e in np.arange(n_events):
        if np.any(board_data[e]-pedestal>=300):
            evt_no = header[e][1]
            ts = header[e][2]
            plt.figure(figsize=(8,6))
            plt.plot(strips, board_data[e]-pedestal)
            plt.title("Board: {}, Event: {}, head_evt_id: {}, ts: {}".format(b,e, evt_no, ts))
            plt.ylim(0,2000 if np.max(board_data[e])<=2000 else np.max(board_data[e]))
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9eee68289f1e> in <module>
#       8     for e in np.arange(n_events):
#       9         if np.any(board_data[e]-pedestal>=300):
# ---> 10             evt_no = header[e][1]
#      11             ts = header[e][2]
#      12             plt.figure(figsize=(8,6))
#
# TypeError: 'Header' object is not subscriptable

# %%
b=8
board_data = data.board_data(b)
n_events = len(board_data)
pedestal = data._avg_data(b)
noise = data._noise(b)
header = data.header_data(b)
for e in np.arange(20):
    evt_no = header[e][1]
    ts = header[e][2]
    plt.figure(figsize=(8,6))
    plt.plot(strips, board_data[e]-pedestal)
    plt.title("Board: {}, Event: {}, head_evt_id: {}, ts: {}".format(b,e, evt_no, ts))
    plt.ylim(0,2000 if np.max(board_data[e])<=2000 else np.max(board_data[e]))
    plt.show()

# %%
old_trigg_board = '../farm_data/old_trigger_board/Run000109218.dat'

# %%
data_old_tb = MarocData(old_trigg_board)

# %%
evt_id_old_8 = data_old_tb.header_data(8)[:,1]
evt_id_old_9 = data_old_tb.header_data(9)[:,1]
ts_old_8 = data_old_tb.header_data(8)[:,2]
ts_old_9 = data_old_tb.header_data(9)[:,2]

# %%
ts_old_8
# Out:
# array([2716893121,   43375510,   54498993, ..., 2255454475, 2255702764,
#        2256967065])

# %%
ts_old_9
# Out:
# array([2715232080,   40285499,   51408982, ..., 2252612752, 2253877054,
#        2254275117])

# %%
evt_id_old_8
# Out:
# array([15360,     1,     2, ...,  1199,  1200,  1201])

# %%
evt_id_old_9
# Out:
# array([15360,     1,     2, ...,  1200,  1201,  1202])

# %%
evt_id_new_8 = data.header_data(8)[:,1]
evt_id_new_9 = data.header_data(9)[:,1]
ts_new_8 = data.header_data(8)[:,2]
ts_new_9 = data.header_data(8)[:,2]

# %%
ts_new_8
# Out:
# array([ 102386825,  104169890,  104224279, ..., 1784600546, 1789121484,
#        1789928618])

# %%
ts_new_9
# Out:
# array([ 102386825,  104169890,  104224279, ..., 1784600546, 1789121484,
#        1789928618])

# %%
evt_id_new_8
# Out:
# array([  77,   78,   79, ..., 1348, 1349, 1350])

# %%
evt_id_new_9
# Out:
# array([  76,   77,   78, ..., 1347, 1348, 1349])

# %%
np.unique(evt_id_new_8).shape
# Out:
# (1251,)

# %%
np.unique(evt_id_new_9).shape
# Out:
# (1273,)
